# %% [markdown]
# <tr>
#         <td width="15%">
#         </td>
#         <td>
#             <div align="left">
#                 <font size=25px>
#                     <b>  Factors influence the home prices across U.S
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>

# %% [markdown]
# Objective:
#
# Found publicly available data for key factors that influence US home prices nationally. Then, built a data science model that explains how these factors impacted home prices over the last 20 years.
#
# The project aims to build a data science model to predict U.S. home prices based on key economic factors over the last 20 years.

# %% [markdown]
# The following variables are chosen for the study-
#
# Unemployment Rate
#
# Employment Rate
#
# Per Capita GDP
#
# Real Median Household Income
#
# Construction Prices
#
# CPI
#
# Interest Rates
#
# Working Population
#
# Mortgage
#
# Housing subsidies
#
# Number of Households
#
# As a proxy to the home prices, S&P CASE-SHILLER Index is used.

# %%
import numpy as np
import pandas as pd

# %%
df1=pd.read_csv("/content/CSUSHPISA New.csv")

# %%
df1.tail()
# Out:
#            DATE  CSUSHPISA
# 247  1-Aug-2022    301.473
# 248  1-Sep-2022    299.353
# 249  1-Oct-2022    298.873
# 250  1-Nov-2022    298.269
# 251  1-Dec-2022    297.413

# %%
#df1["Year"] = pd.DatetimeIndex(df1["DATE"]).year
#df1["Month"] = pd.DatetimeIndex(df1["DATE"]).month

# %%
#df1.shape

# %%
df1.head()
# Out:
#          DATE  CSUSHPISA
# 0  1-Jan-2002    117.144
# 1  1-Feb-2002    117.845
# 2  1-Mar-2002    118.687
# 3  1-Apr-2002    119.611
# 4  1-May-2002    120.724

# %%
df2=pd.read_csv("/content/Employment Rate.csv")
df2.head()
# Out:
#          DATE    EmpRate
# 0  1-Jan-2002  72.016140
# 1  1-Feb-2002  72.333005
# 2  1-Mar-2002  72.131883
# 3  1-Apr-2002  71.914847
# 4  1-May-2002  72.026012

# %%
df3=pd.read_csv("/content/Per Capita GDP (2)2.csv")
df3.head()
# Out:
#          DATE  Per_capita_GDP
# 0  1-Jan-2002           50091
# 1  1-Apr-2002           50286
# 2  1-Jul-2002           50362
# 3  1-Oct-2002           50302
# 4  1-Jan-2003           50462

# %%
df4=pd.read_csv("/content/Interest Rate.csv")
df4.head()
# Out:
#          DATE  FEDFUNDS
# 0  1-Jan-2002      1.73
# 1  1-Feb-2002      1.74
# 2  1-Mar-2002      1.73
# 3  1-Apr-2002      1.75
# 4  1-May-2002      1.75

# %%
df5=pd.read_csv("/content/mortgage.csv")
df5.head()
# Out:
#          DATE  mortgage
# 0  1-Jan-2002      1532
# 1  1-Feb-2002      1423
# 2  1-Mar-2002      1358
# 3  1-Apr-2002      1397
# 4  1-May-2002      1467

# %%
df6=pd.read_csv("/content/UNRATE.csv")
df6.head()
# Out:
#          DATE  UNRATE
# 0  1-Jan-2002     5.7
# 1  1-Feb-2002     5.7
# 2  1-Mar-2002     5.7
# 3  1-Apr-2002     5.9
# 4  1-May-2002     5.8

# %%
df7=pd.read_csv("/content/Construction Prices.csv")
df7.head()
# Out:
#          DATE  Cons_Material
# 0  1-Jan-2002          142.0
# 1  1-Feb-2002          142.2
# 2  1-Mar-2002          143.2
# 3  1-Apr-2002          143.5
# 4  1-May-2002          143.8

# %%
df8=pd.read_csv("/content/Consumer Price Index.csv")
df8.head()
# Out:
#          DATE    CPI
# 0  1-Jan-2002  177.7
# 1  1-Feb-2002  178.0
# 2  1-Mar-2002  178.5
# 3  1-Apr-2002  179.3
# 4  1-May-2002  179.5

# %%
df9=pd.read_csv("/content/Number of Households.csv")
df9.head()
# Out:
#          DATE  No_households
# 0  1-Jan-2002         109297
# 1  1-Jan-2003         111278
# 2  1-Jan-2004         112000
# 3  1-Jan-2005         113343
# 4  1-Jan-2006         114384

# %%
df10=pd.read_csv("/content/Housing subsides.csv")
df10.head()
# Out:
#          DATE  subsidy
# 0  1-Jan-2002   24.183
# 1  1-Jan-2003   25.930
# 2  1-Jan-2004   27.201
# 3  1-Jan-2005   27.651
# 4  1-Jan-2006   28.604

# %%
df11=pd.read_csv("/content/Real Median Household Income.csv")
df11.head()
# Out:
#          DATE  median_income
# 0  1-Jan-2002          65820
# 1  1-Jan-2003          65860
# 2  1-Jan-2004          65760
# 3  1-Jan-2005          66780
# 4  1-Jan-2006          67520

# %%
df12=pd.read_csv("/content/Working Population.csv")
df12.head()
# Out:
#          DATE  working_age_pop
# 0  1-Jan-2002      182566431.9
# 1  1-Feb-2002      182798390.1
# 2  1-Mar-2002      183078312.4
# 3  1-Apr-2002      183260453.0
# 4  1-May-2002      183508212.5

# %%
df=df1.merge(df2,on="DATE",how='left')

# %%
df.head()
# Out:
#          DATE  CSUSHPISA    EmpRate
# 0  1-Jan-2002    117.144  72.016140
# 1  1-Feb-2002    117.845  72.333005
# 2  1-Mar-2002    118.687  72.131883
# 3  1-Apr-2002    119.611  71.914847
# 4  1-May-2002    120.724  72.026012

# %%
df=df.merge(df3,on='DATE',how='left')

# %%
df=df.merge(df4,on='DATE',how='left')

# %%
df=df.merge(df5,on='DATE',how='left')

# %%
df=df.merge(df6,on='DATE',how='left')

# %%
df=df.merge(df7,on='DATE',how='left')

# %%
df=df.merge(df8,on='DATE',how='left')

# %%
df=df.merge(df9,on='DATE',how='left')

# %%
df=df.merge(df10,on='DATE',how='left')

# %%
df=df.merge(df11,on='DATE',how='left')

# %%
df=df.merge(df12,on='DATE',how='left')

# %%
df.head()
# Out:
#          DATE  CSUSHPISA    EmpRate  Per_capita_GDP  FEDFUNDS  mortgage  \
# 0  1-Jan-2002    117.144  72.016140         50091.0      1.73      1532
# 1  1-Feb-2002    117.845  72.333005             NaN      1.74      1423
# 2  1-Mar-2002    118.687  72.131883             NaN      1.73      1358
# 3  1-Apr-2002    119.611  71.914847         50286.0      1.75      1397
# 4  1-May-2002    120.724  72.026012             NaN      1.75      1467
#
#    UNRATE  Cons_Material    CPI  No_households  subsidy  median_income  \
# 0     5.7          142.0  177.7       109297.0   24.183        65820.0
# 1     5.7          142.2  178.0            NaN      NaN            NaN
# 2     5.7          143.2  178.5            NaN      NaN            NaN
# 3     5.9          143.5  179.3            NaN      NaN            NaN
# 4     5.8          143.8  179.5            NaN      NaN            NaN
#
#    working_age_pop
# 0      182566431.9
# 1      182798390.1
# 2      183078312.4
# 3      183260453.0
# ...

# %%
df.tail()
# Out:
#            DATE  CSUSHPISA    EmpRate  Per_capita_GDP  FEDFUNDS  mortgage  \
# 247  1-Aug-2022    301.473  71.452559             NaN      2.33      1412
# 248  1-Sep-2022    299.353  71.418877             NaN      2.56      1619
# 249  1-Oct-2022    298.873  71.273773         65783.0      3.08      1469
# 250  1-Nov-2022    298.269  71.334177             NaN      3.78      1501
# 251  1-Dec-2022    297.413  71.587071             NaN      4.10      1260
#
#      UNRATE  Cons_Material      CPI  No_households  subsidy  median_income  \
# 247     3.7        342.753  295.320            NaN      NaN            NaN
# 248     3.5        336.464  296.539            NaN      NaN            NaN
# 249     3.7        333.796  297.987            NaN      NaN            NaN
# 250     3.6        330.369  298.598            NaN      NaN            NaN
# 251     3.5        326.449  298.990            NaN      NaN            NaN
#
#      working_age_pop
# 247      207370651.0
# 248      207453580.5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 252 entries, 0 to 251
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   DATE             252 non-null    object
#  1   CSUSHPISA        252 non-null    float64
#  2   EmpRate          252 non-null    float64
#  3   Per_capita_GDP   84 non-null     float64
#  4   FEDFUNDS         252 non-null    float64
#  5   mortgage         252 non-null    int64
#  6   UNRATE           252 non-null    float64
#  7   Cons_Material    252 non-null    float64
#  8   CPI              252 non-null    float64
#  9   No_households    21 non-null     float64
#  10  subsidy          21 non-null     float64
#  11  median_income    21 non-null     float64
#  12  working_age_pop  252 non-null    float64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 27.6+ KB

# %%
df.isnull().sum()
# Out:
# DATE                 0
# CSUSHPISA            0
# EmpRate              0
# Per_capita_GDP     168
# FEDFUNDS             0
# mortgage             0
# UNRATE               0
# Cons_Material        0
# CPI                  0
# No_households      231
# subsidy            231
# median_income      231
# working_age_pop      0
# dtype: int64

# %%
df['Per_capita_GDP']=df['Per_capita_GDP'].interpolate()

# %%
df.isnull().sum()
# Out:
# DATE                 0
# CSUSHPISA            0
# EmpRate              0
# Per_capita_GDP       0
# FEDFUNDS             0
# mortgage             0
# UNRATE               0
# Cons_Material        0
# CPI                  0
# No_households      231
# subsidy            231
# median_income      231
# working_age_pop      0
# dtype: int64

# %%
df['No_households']=df['No_households'].fillna(method='ffill')

# %%
df['subsidy']=df['subsidy'].fillna(method='ffill')

# %%
df['median_income']=df['median_income'].fillna(method='ffill')

# %%
df.head()
# Out:
#          DATE  CSUSHPISA    EmpRate  Per_capita_GDP  FEDFUNDS  mortgage  \
# 0  1-Jan-2002    117.144  72.016140    50091.000000      1.73      1532
# 1  1-Feb-2002    117.845  72.333005    50156.000000      1.74      1423
# 2  1-Mar-2002    118.687  72.131883    50221.000000      1.73      1358
# 3  1-Apr-2002    119.611  71.914847    50286.000000      1.75      1397
# 4  1-May-2002    120.724  72.026012    50311.333333      1.75      1467
#
#    UNRATE  Cons_Material    CPI  No_households  subsidy  median_income  \
# 0     5.7          142.0  177.7       109297.0   24.183        65820.0
# 1     5.7          142.2  178.0       109297.0   24.183        65820.0
# 2     5.7          143.2  178.5       109297.0   24.183        65820.0
# 3     5.9          143.5  179.3       109297.0   24.183        65820.0
# 4     5.8          143.8  179.5       109297.0   24.183        65820.0
#
#    working_age_pop
# 0      182566431.9
# 1      182798390.1
# 2      183078312.4
# 3      183260453.0
# ...

# %%
df.isnull().sum()
# Out:
# DATE               0
# CSUSHPISA          0
# EmpRate            0
# Per_capita_GDP     0
# FEDFUNDS           0
# mortgage           0
# UNRATE             0
# Cons_Material      0
# CPI                0
# No_households      0
# subsidy            0
# median_income      0
# working_age_pop    0
# dtype: int64

# %%
df.to_csv("prepared_dataset.csv")

# %%
df = pd.read_csv("prepared_dataset.csv").set_index("DATE")

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'CSUSHPISA', 'EmpRate', 'Per_capita_GDP', 'FEDFUNDS',
#        'mortgage', 'UNRATE', 'Cons_Material', 'CPI', 'No_households',
#        'subsidy', 'median_income', 'working_age_pop'],
#       dtype='object')

# %%
df.drop(columns='Unnamed: 0',axis=1,inplace=True)

# %% [markdown]
# **Exploratory Data Analysis (EDA)**
#
# Summary Statistics:
# Calculate and display summary statistics for each variable, including mean, median, standard deviation, minimum, and maximum values. This gives you an overview of the data's central tendencies and variability.

# %%
df.describe()
# Out:
#         CSUSHPISA     EmpRate  Per_capita_GDP    FEDFUNDS     mortgage  \
# count  252.000000  252.000000      252.000000  252.000000   252.000000
# mean   177.877333   69.613311    57048.246032    1.319008  1829.067460
# std     42.145732    2.072157     4164.202565    1.542732   420.645245
# min    117.144000   60.193856    50091.000000    0.050000  1229.000000
# 25%    146.768500   67.798317    54205.833333    0.120000  1482.500000
# 50%    170.175500   70.273096    55677.000000    0.715000  1650.000000
# 75%    194.020250   71.372429    60008.250000    1.935000  2181.500000
# max    304.724000   72.333005    65783.000000    5.260000  2809.000000
#
#            UNRATE  Cons_Material         CPI  No_households     subsidy  \
# count  252.000000     252.000000  252.000000     252.000000  252.000000
# mean     6.001190     209.573222  227.634710  120770.761905   34.177714
# std      1.985615      45.902963   28.868851    6496.223206    6.274362
# ...

# %% [markdown]
# **Correlation Analysis:**
#
# Calculate the correlation matrix to measure the linear relationships between variables.

# %%
corr=df.corr()
corr
# Out:
#                  CSUSHPISA   EmpRate  Per_capita_GDP  FEDFUNDS  mortgage  \
# CSUSHPISA         1.000000  0.199022        0.904059  0.113765 -0.349435
# EmpRate           0.199022  1.000000        0.007038  0.708546 -0.897380
# Per_capita_GDP    0.904059  0.007038        1.000000 -0.105145 -0.162574
# FEDFUNDS          0.113765  0.708546       -0.105145  1.000000 -0.653298
# mortgage         -0.349435 -0.897380       -0.162574 -0.653298  1.000000
# UNRATE           -0.475602 -0.848741       -0.429107 -0.514168  0.805335
# Cons_Material     0.898973 -0.109856        0.917827 -0.225555 -0.005750
# CPI               0.822246 -0.236098        0.947312 -0.303169  0.084668
# No_households     0.748982 -0.266324        0.937986 -0.339510  0.095676
# subsidy           0.845075 -0.247718        0.931330 -0.315860  0.071428
# median_income     0.831518  0.228674        0.847451  0.081261 -0.455233
# working_age_pop   0.619809 -0.398896        0.852789 -0.359252  0.245905
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
warnings.filterwarnings("ignore")

# %%
# Visualize correlations using a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.show()

# %% [markdown]
# **Time Series Analysis:**
#
# For time-dependent variables like 'CSUSHPISA,' use time series decomposition to separate trends, seasonality, and residuals. Plot these components to understand the patterns over time.

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
decomposition = seasonal_decompose(df['CSUSHPISA'], model='additive', period=12)
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

# %%
plt.figure(figsize=(12, 8))

plt.subplot(4, 1, 1)
plt.plot(df['CSUSHPISA'], label='Original Time Series')
plt.legend()
plt.title('Original Time Series')

plt.subplot(4, 1, 2)
plt.plot(trend, label='Trend')
plt.legend()
plt.title('Trend Component')

plt.subplot(4, 1, 3)
plt.plot(seasonal, label='Seasonality')
plt.legend()
plt.title('Seasonal Component')

plt.subplot(4, 1, 4)
plt.plot(residual, label='Residuals')
plt.legend()
plt.title('Residuals')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plot_acf(df['CSUSHPISA'], lags=40, ax=plt.gca(), title='Autocorrelation Plot')

plt.subplot(1, 2, 2)
plot_pacf(df['CSUSHPISA'], lags=40, ax=plt.gca(), title='Partial Autocorrelation Plot')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Data Visualization:**
#
# Visualize the data using various plots and graphs to understand its distribution and trends.

# %%
sns.pairplot(df)

# %%
df.columns
# Out:
# Index(['CSUSHPISA', 'EmpRate', 'Per_capita_GDP', 'FEDFUNDS', 'mortgage',
#        'UNRATE', 'Cons_Material', 'CPI', 'No_households', 'subsidy',
#        'median_income', 'working_age_pop'],
#       dtype='object')

# %%
factors=['CSUSHPISA','EmpRate','Per_capita_GDP','FEDFUNDS','mortgage','UNRATE','Cons_Material','CPI','No_households','subsidy','median_income','working_age_pop']

# %%
plt.figure(figsize=(13, 8))
df[factors].hist(bins=20, alpha=0.5, layout=(4, 4), figsize=(15, 10))
plt.suptitle('Histograms and Kernel Density Plots')
plt.show()

# %% [markdown]
# **Extract features and target**

# %%
# Separating the target variable and the independent variable
X=df.drop(['CSUSHPISA'],axis=1)
y=df['CSUSHPISA']

# %%
fig=px.scatter(df,x=df['EmpRate'], y=df['CSUSHPISA'],trendline='ols',trendline_color_override='green')
fig.show()
results = px.get_trendline_results(fig)
print(results)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=px.scatter(df,x=df['Per_capita_GDP'], y=df['CSUSHPISA'],trendline='ols',trendline_color_override='green')
fig.show()
results = px.get_trendline_results(fig)
print(results)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=px.scatter(df,x=df['FEDFUNDS'], y=df['CSUSHPISA'],trendline='ols',trendline_color_override='green')
fig.show()
results = px.get_trendline_results(fig)
print(results)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=px.scatter(df,x=df['mortgage'], y=df['CSUSHPISA'],trendline='ols',trendline_color_override='green')
fig.show()
results = px.get_trendline_results(fig)
print(results)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=px.scatter(df,x=df['UNRATE'], y=df['CSUSHPISA'],trendline='ols',trendline_color_override='green')
fig.show()
results = px.get_trendline_results(fig)
print(results)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=px.scatter(df,x=df['Cons_Material'], y=df['CSUSHPISA'],trendline='ols',trendline_color_override='green')
fig.show()
results = px.get_trendline_results(fig)
print(results)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=px.scatter(df,x=df['CPI'], y=df['CSUSHPISA'],trendline='ols',trendline_color_override='green')
fig.show()
results = px.get_trendline_results(fig)
print(results)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=px.scatter(df,x=df['No_households'], y=df['CSUSHPISA'],trendline='ols',trendline_color_override='green')
fig.show()
results = px.get_trendline_results(fig)
print(results)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=px.scatter(df,x=df['subsidy'], y=df['CSUSHPISA'],trendline='ols',trendline_color_override='green')
fig.show()
results = px.get_trendline_results(fig)
print(results)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=px.scatter(df,x=df['median_income'], y=df['CSUSHPISA'],trendline='ols',trendline_color_override='green')
fig.show()
results = px.get_trendline_results(fig)
print(results)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=px.scatter(df,x=df['working_age_pop'], y=df['CSUSHPISA'],trendline='ols',trendline_color_override='green')
fig.show()
results = px.get_trendline_results(fig)
print(results)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Calculate correlation coefficients**

# %%
correlations = X.apply(lambda column: np.abs(column.corr(y)))

# Sort correlations in ascending order
sorted_correlations = correlations.sort_values()

# Display features with lower correlation
print("Features with Lower Correlation to Target:")
print(sorted_correlations)
# Out:
# Features with Lower Correlation to Target:
# FEDFUNDS           0.113765
# EmpRate            0.199022
# mortgage           0.349435
# UNRATE             0.475602
# working_age_pop    0.619809
# No_households      0.748982
# CPI                0.822246
# median_income      0.831518
# subsidy            0.845075
# Cons_Material      0.898973
# Per_capita_GDP     0.904059
# dtype: float64

# %% [markdown]
# Based on the provided correlation coefficients:
#
# Highest Correlation:
#
# The variable with the highest correlation with the target variable ('CSUSHPISA') is 'Per_Capita_GDP' with a correlation coefficient of 0.904059. This feature shows a strong positive linear relationship with home prices.
#
# Other Strong Correlations:
#
# 'Cons_Material': (0.898973), 'Subsidy': (0.845075),'median_income': (0.831518), and 'CPI': (0.822246) also have strong positive correlations.
#
# Moderate Correlations:
#
# 'No_Households': (0.748982), and 'working_age_pop': (0.619809) have moderate positive correlations.
#
# Lower Correlations:
#
# 'UNRATE': (0.475602), 'Mortgage': (0.349435), 'EmpRate': (0.199022), and 'FEDFUNDS': (0.113765) have lower correlations.

# %% [markdown]
# **Models building**

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
x=df.drop(columns=['mortgage','EmpRate','FEDFUNDS','CSUSHPISA'],axis=1)
y=df['CSUSHPISA']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# Standard Scaling

# %%
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %% [markdown]
# Linear Regression

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_percentage_error,r2_score,mean_absolute_error

# %%
from sklearn.linear_model import LinearRegression
LR = LinearRegression()
LR_model = LR.fit(x_train_scaled,y_train)
LR_model
# Out:
# LinearRegression()

# %%
y_pred = LR_model.predict(x_test_scaled)

# %%
MLR_R2=r2_score(y_test,y_pred)
MLR_R2
# Out:
# 0.9193057733860643

# %%
MLR_rmse=np.sqrt(mean_squared_error(y_test,y_pred))
print('RMSE = ',MLR_rmse)
# Out:
# RMSE =  9.969289102752454

# %%
MLR_mape=mean_absolute_percentage_error(y_test,y_pred)
print('MAPE = ',MLR_mape)
# Out:
# MAPE =  0.03350034608798879

# %%
MLR_mae=mean_absolute_error(y_test,y_pred)
print('MAE =',MLR_mae)
# Out:
# MAE = 5.884464891437395

# %%
cols = ['Model', 'R-squared','RMSE','MAPE','MAE']

# %%
result_tabulation = pd.DataFrame(columns = cols)

# %%
OLS_metrics = pd.Series({'Model': "Linear Regression(OLS)",
                 'R-squared' : MLR_R2, 'RMSE' :MLR_rmse, 'MAPE': MLR_mape, 'MAE': MLR_mae})

# %%
result_tabulation = result_tabulation.append(OLS_metrics , ignore_index = True)

# %%
result_tabulation
# Out:
#                     Model  R-squared      RMSE    MAPE       MAE
# 0  Linear Regression(OLS)   0.919306  9.969289  0.0335  5.884465

# %% [markdown]
# Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor
DT = DecisionTreeRegressor()
DT_model = DT.fit(x_train_scaled,y_train)
DT_model
# Out:
# DecisionTreeRegressor()

# %%
dt_y_pred = DT_model.predict(x_test_scaled)

# %%
DT_R2=r2_score(y_test,dt_y_pred)
DT_R2
# Out:
# 0.9959157010254206

# %%
DT_rmse=np.sqrt(mean_squared_error(y_test,dt_y_pred))
print('RMSE = ',DT_rmse)
# Out:
# RMSE =  2.2428577053113536

# %%
DT_mape=mean_absolute_percentage_error(y_test,dt_y_pred)
print('MAPE = ',DT_mape)
# Out:
# MAPE =  0.009672703520369294

# %%
DT_mae=mean_absolute_error(y_test,dt_y_pred)
print('MAE =',DT_mae)
# Out:
# MAE = 1.6511176470588231

# %%
Decision_Tree = pd.Series({'Model': "Decision Tree",
                 'R-squared' : DT_R2, 'RMSE' :DT_rmse, 'MAPE': DT_mape, 'MAE': DT_mae})

# %%
result_tabulation = result_tabulation.append(Decision_Tree , ignore_index = True)

# %%
result_tabulation
# Out:
#                     Model  R-squared      RMSE      MAPE       MAE
# 0  Linear Regression(OLS)   0.919306  9.969289  0.033500  5.884465
# 1           Decision Tree   0.995916  2.242858  0.009673  1.651118

# %% [markdown]
# ElasticNet

# %%
from sklearn.linear_model import ElasticNet

# %%
alpha = 0.1  # Regularization strength
l1_ratio = 0.5  # Elastic Net mixing parameter (0 <= l1_ratio <= 1)
elastic_net = ElasticNet(alpha=alpha, l1_ratio=l1_ratio, random_state=42)
elastic_net.fit(x_train_scaled, y_train)
# Out:
# ElasticNet(alpha=0.1, random_state=42)

# %%
EN_y_pred = elastic_net.predict(x_test_scaled)

# %%
EN_R2=r2_score(y_test,EN_y_pred)
EN_R2
# Out:
# 0.9220615680076131

# %%
EN_rmse=np.sqrt(mean_squared_error(y_test,EN_y_pred))
print('RMSE = ',EN_rmse)
# Out:
# RMSE =  9.79757937771589

# %%
EN_mape=mean_absolute_percentage_error(y_test,EN_y_pred)
print('MAPE = ',EN_mape)
# Out:
# MAPE =  0.04157768168505971

# %%
EN_mae=mean_absolute_error(y_test,EN_y_pred)
print('MAE =',EN_mae)
# Out:
# MAE = 6.976361018245968

# %%
EN = pd.Series({'Model': "ElasticNet Regularization",
                 'R-squared' : EN_R2, 'RMSE' :EN_rmse, 'MAPE': EN_mape, 'MAE': EN_mae})

# %%
result_tabulation = result_tabulation.append(EN , ignore_index = True)
result_tabulation
# Out:
#                        Model  R-squared      RMSE      MAPE       MAE
# 0     Linear Regression(OLS)   0.919306  9.969289  0.033500  5.884465
# 1              Decision Tree   0.995916  2.242858  0.009673  1.651118
# 2  ElasticNet Regularization   0.922062  9.797579  0.041578  6.976361

# %% [markdown]
# Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
RF = RandomForestRegressor()
RF_model = RF.fit(x_train_scaled,y_train)
RF_model
# Out:
# RandomForestRegressor()

# %%
RF_y_pred = RF_model.predict(x_test_scaled)

# %%
RF_R2=r2_score(y_test,RF_y_pred)
RF_R2
# Out:
# 0.9981847517435074

# %%
RF_rmse=np.sqrt(mean_squared_error(y_test,RF_y_pred))
print('MSE = ',RF_rmse)
# Out:
# MSE =  1.4952402279219559

# %%
RF_mape=mean_absolute_percentage_error(y_test,RF_y_pred)
print('MAPE = ',RF_mape)
# Out:
# MAPE =  0.00553045244489002

# %%
RF_mae=mean_absolute_error(y_test,RF_y_pred)
print('MAE =',RF_mae)
# Out:
# MAE = 0.9904137254902091

# %%
Random_Forest = pd.Series({'Model': "Random Forest",
                 'R-squared' : RF_R2, 'RMSE' :RF_rmse, 'MAPE': RF_mape, 'MAE': RF_mae})

# %%
result_tabulation = result_tabulation.append( Random_Forest, ignore_index = True)

# %%
result_tabulation
# Out:
#                        Model  R-squared      RMSE      MAPE       MAE
# 0     Linear Regression(OLS)   0.919306  9.969289  0.033500  5.884465
# 1              Decision Tree   0.995916  2.242858  0.009673  1.651118
# 2  ElasticNet Regularization   0.922062  9.797579  0.041578  6.976361
# 3              Random Forest   0.998185  1.495240  0.005530  0.990414

# %% [markdown]
# Support vector Machine

# %%
from sklearn.svm import LinearSVR
SVR_mod = LinearSVR()
SVR_model = SVR_mod.fit(x_train_scaled,y_train)
SVR_model
# Out:
# LinearSVR()

# %%
SVR_y_pred = SVR_model.predict(x_test_scaled)

# %%
SVR_R2=r2_score(y_test,SVR_y_pred)
SVR_R2
# Out:
# 0.7097271255502569

# %%
SVR_rmse=np.sqrt(mean_squared_error(y_test,SVR_y_pred))
print('MSE = ',SVR_rmse)
# Out:
# MSE =  18.908025764989873

# %%
SVR_mape=mean_absolute_percentage_error(y_test,SVR_y_pred)
print('MAPE = ',SVR_mape)
# Out:
# MAPE =  0.06814347682938239

# %%
SVR_mae=mean_absolute_error(y_test,SVR_y_pred)
print('MAE =',SVR_mae)
# Out:
# MAE = 12.383808512017291

# %%
SVR = pd.Series({'Model': "Support Vector",
                 'R-squared' : SVR_R2, 'RMSE' :SVR_rmse, 'MAPE': SVR_mape, 'MAE': SVR_mae})

# %%
result_tabulation=result_tabulation.append(SVR,ignore_index=True)
result_tabulation
# Out:
#                        Model  R-squared       RMSE      MAPE        MAE
# 0     Linear Regression(OLS)   0.919306   9.969289  0.033500   5.884465
# 1              Decision Tree   0.995916   2.242858  0.009673   1.651118
# 2  ElasticNet Regularization   0.922062   9.797579  0.041578   6.976361
# 3              Random Forest   0.998185   1.495240  0.005530   0.990414
# 4             Support Vector   0.709727  18.908026  0.068143  12.383809

# %% [markdown]
# Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
model_GBR = GradientBoostingRegressor(
    loss='squared_error',              # Loss function: 'ls' for least squares regression
    n_estimators=100,       # Number of boosting stages (trees)
    learning_rate=0.1,      # Step size shrinking to prevent overfitting
    max_depth=3,            # Maximum depth of individual trees
    min_samples_split=2,    # Minimum number of samples required to split an internal node
    min_samples_leaf=1,     # Minimum number of samples required to be at a leaf node
    random_state=42         # Seed for reproducibility
)

# %%
GBR_model=model_GBR.fit(x_train_scaled, y_train)

# %%
GBR_y_pred = model_GBR.predict(x_test_scaled)

# %%
GBR_R2=r2_score(y_test,GBR_y_pred)
GBR_R2
# Out:
# 0.9984117943402738

# %%
GBR_rmse=np.sqrt(mean_squared_error(y_test,GBR_y_pred))
print('RMSE = ',GBR_rmse)
# Out:
# RMSE =  1.3986090312942463

# %%
GBR_mape=mean_absolute_percentage_error(y_test,GBR_y_pred)
print('MAPE = ',GBR_mape)
# Out:
# MAPE =  0.006668759178840222

# %%
GBR_mae=mean_absolute_error(y_test,GBR_y_pred)
print('MAE =',GBR_mae)
# Out:
# MAE = 1.1136588461271535

# %%
GBR= pd.Series({'Model': "Gradient Boosting Regressor",
                 'R-squared' : GBR_R2, 'RMSE' :GBR_rmse, 'MAPE': GBR_mape, 'MAE': GBR_mae})

# %%
result_tabulation=result_tabulation.append(GBR,ignore_index=True)
result_tabulation
# Out:
#                          Model  R-squared       RMSE      MAPE        MAE
# 0       Linear Regression(OLS)   0.919306   9.969289  0.033500   5.884465
# 1                Decision Tree   0.995916   2.242858  0.009673   1.651118
# 2    ElasticNet Regularization   0.922062   9.797579  0.041578   6.976361
# 3                Random Forest   0.998185   1.495240  0.005530   0.990414
# 4               Support Vector   0.709727  18.908026  0.068143  12.383809
# 5  Gradient Boosting Regressor   0.998412   1.398609  0.006669   1.113659

# %% [markdown]
# XG Boosting

# %%
import xgboost as xgb
from xgboost import XGBRegressor

# %%
model_XGBR = XGBRegressor(
    n_estimators=100,         # Number of boosting rounds (trees)
    learning_rate=0.1,        # Step size shrinking to prevent overfitting
    max_depth=3,              # Maximum depth of individual trees
    min_child_weight=1,       # Minimum sum of instance weight (hessian) needed in a child
    gamma=0,                  # Minimum loss reduction required to make a further partition on a leaf node
    subsample=1,              # Fraction of samples used for fitting the trees
    colsample_bytree=1,       # Fraction of features used for fitting the trees
    reg_alpha=0,              # L1 regularization term on weights
    reg_lambda=1,             # L2 regularization term on weights
    random_state=42           # Seed for reproducibility
)

# %%
XGB_model=model_XGBR.fit(x_train_scaled, y_train)

# %%
XGBR_y_pred = model_XGBR.predict(x_test_scaled)

# %%
XGBR_R2=r2_score(y_test,XGBR_y_pred)
XGBR_R2
# Out:
# 0.9967168567339431

# %%
XGBR_rmse=np.sqrt(mean_squared_error(y_test,XGBR_y_pred))
print('RMSE = ',XGBR_rmse)
# Out:
# RMSE =  2.010887969267756

# %%
XGBR_mape=mean_absolute_percentage_error(y_test,XGBR_y_pred)
print('MAPE = ',XGBR_mape)
# Out:
# MAPE =  0.007744440003610231

# %%
XGBR_mae=mean_absolute_error(y_test,XGBR_y_pred)
print('MAE =',XGBR_mae)
# Out:
# MAE = 1.3153664036171107

# %%
XGBR= pd.Series({'Model': "XG Boosting Regressor",
                 'R-squared' : XGBR_R2, 'RMSE' :XGBR_rmse, 'MAPE': XGBR_mape, 'MAE': XGBR_mae})

# %%
result_tabulation=result_tabulation.append(XGBR,ignore_index=True)
result_tabulation
# Out:
#                          Model  R-squared       RMSE      MAPE        MAE
# 0       Linear Regression(OLS)   0.919306   9.969289  0.033500   5.884465
# 1                Decision Tree   0.995916   2.242858  0.009673   1.651118
# 2    ElasticNet Regularization   0.922062   9.797579  0.041578   6.976361
# 3                Random Forest   0.998185   1.495240  0.005530   0.990414
# 4               Support Vector   0.709727  18.908026  0.068143  12.383809
# 5  Gradient Boosting Regressor   0.998412   1.398609  0.006669   1.113659
# 6        XG Boosting Regressor   0.996717   2.010888  0.007744   1.315366

# %% [markdown]
# **Conclusion:**
#
# Random Forest and Gradient Boosting appear to be strong contenders, as they have low RMSE and high R-squared values. Additionally, both models provide insights into feature importance.
#
# XG Boosting also performs well but with a slightly lower R-squared compared to Random Forest and Gradient Boosting.
#
# Linear Regression and ElasticNet have higher RMSE values, indicating potential limitations in predictive accuracy.
#
# SVR has a considerably higher RMSE and lower R-squared, suggesting lower performance compared to other models.
#
# This means that, according to the model, changes in these features have a notable impact on the predictions of U.S. home prices. For example, if 'CPI' increases, it suggests that changes in the cost of living might influence home prices.
#
# Understanding feature importance is crucial for making informed decisions, refining models, and gaining insights into the factors driving the predictions, which is especially valuable in fields like economics, finance, or real estate where interpretability is essential.
